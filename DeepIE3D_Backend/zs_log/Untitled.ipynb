# %%
import datetime

dt=datetime.datetime.now()
print(str(dt).split('.')[0])
# Out:
# 2021-01-21 15:20:15

# %%
import glob
files=glob.glob('zs_log/*')
files=sorted(files)

print(files[0])
# Out:
# zs_log/2021-01-21 12:08:59.csv

# %%
import csv
array=[[4,5],[5,2],[5,5],[5,7],[6,1],[6,9],[7,6],[8,1],[9,8]]

for i in range(len(array)):
    with open(files[array[i][0]-1],'r') as f:
        reader=csv.reader(f)
        l=[row for row in reader]
        with open('initial_zs.csv','a') as ff:
            writer=csv.writer(ff)
            writer.writerow(l[array[i][1]-1])

# %%
from initial import Initial
INI=Initial()

# %%
print(INI.get_zs(0))
# Out:
# [1.4636085033416748, 1.2602933645248413, -0.22907082736492157, 0.006790561601519585, 0.2342623621225357, 0.05042468383908272, -0.138035386800766, 1.3412936925888062, 0.9746325016021729, 0.04330642521381378, 2.247012138366699, 1.9936257600784302, -2.7554428577423096, 0.7280794382095337, -0.5973637700080872, -1.1293628215789795, 1.1633262634277344, -0.8317909240722656, 1.5882424116134644, -0.8067213892936707, 0.1791791319847107, 0.6292931437492371, 0.7917601466178894, 0.009815805591642857, 0.5178658366203308, -0.851442813873291, 1.7006516456604004, -0.18417619168758392, 0.05213627964258194, -0.0035815685987472534, 0.21479861438274384, -1.6661235094070435, -1.1325786113739014, 0.578972339630127, 1.0550510883331299, 2.7943732738494873, 1.9310157299041748, -0.06546947360038757, -0.6082754731178284, -0.56829434633255, 0.24977540969848633, -0.35439157485961914, 0.46540409326553345, 0.7203767895698547, 3.031280040740967, 1.5362579822540283, 1.0546965599060059, -0.8536173701286316, 0.13690270
# ...
